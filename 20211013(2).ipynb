# %% [markdown]
# <a href="https://colab.research.google.com/github/REMIEGIA/Remie-Gia-Venus-Pastor---Miss-M./blob/Miss-Evernight/20211013(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 45
b = 256
if b < a:
    print("b is greater than a")
elif a < b:
    print("a is less than b")
# Out:
# a is less than b

# %%
a = 78
b = 238
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 67
b = 55
if b < a:
  print("b is less than a")
# Out:
# b is less than a

# %%
a = 57
b = 57
if b < a:
    print("b is greater than a")
elif a < b:
    print("a is less than b")
else:
    print("a and b are equal")
# Out:
# a and b are equal

# %%
year = eval(input("Please input the year"))

if ((year%400==0) or (year%4==0 and year%100!=0)):
    print("{0} is a leap year".format(year))
else:
  print("{0} is not a leap year".format(year))
# Out:
# Please input the year2003
# 2003 is not a leap year

# %%
c = 3

while c < 7:
  print(c)
  c += 3
# Out:
# 3
# 6

# %%
c = 3

while c < 7:
  print(c)
  if c == 5:
          continue
    #       break
c += 3
# Out:
# Streaming output truncated to the last 5000 lines.
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
c = 3
while c < 7
print(c)
if c ==5:
  break
  b -= 3
